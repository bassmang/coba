# %% [markdown]
# # Environments
# In this notebook we will show four methods for incorporating new SimulatedEnvironments into Coba:
# 1. From an Openml.org dataset with **OpenmlSimulation**
# 2. From local data sets with **CsvSimulation**, **ArffSimulation**, **LibsvmSimulation**, and **ManikSimulation**.
# 3. From Python function definitions with **LambdaSimulation**
# 4. From your own class that implements the **SimulatedEnvironment** interface
#
# ## Environments From Openml.org
#
# Perhaps the easiest way to incorporate new Environments is to load them from Openml.org. Openml is is an online repository of machine learning data sets which currently hosts over 21,000 datasets. Using dataset ids Coba can tap into this repository and download these datasets to create Environments.
#
# To get a sense of how this works let's say we want to build a SimulatedEnvironment from the Covertype data set. We can [do a dataset search](https://www.openml.org/search?type=data) on Openml.org to see if this data set is hosted. [This search](https://www.openml.org/search?q=covertype&type=data) finds several data sets and we simply pick [the first one](https://www.openml.org/d/180). On the dataset's landing page we can look at the URL -- https://www.openml.org/d/180 -- to get the dataset's id of 180. Now, all we have to do to run an experiment with the Covertype data set is:

# %%
from coba.environments import Environments
from coba.learners     import RandomLearner, VowpalEpsilonLearner, VowpalArgsLearner
from coba.experiments  import Experiment
from coba.contexts import CobaContext

CobaContext.cacher.cache_directory = '/coba/coba_cache'
environments = Environments.from_openml(181,take=5000).shuffle(list(range(1, 10)))
#environments = Environments.from_openml(180)

learners     = [RandomLearner(), VowpalEpsilonLearner(epsilon=0.1), VowpalArgsLearner("--cb_explore_adf --epsilon_decay --model_count 1 --interactions xxa --interactions xa --ignore_linear x --random_seed 1"), VowpalArgsLearner("--cb_explore_adf --epsilon_decay --model_count 4 --interactions xxa --interactions xa --ignore_linear x --random_seed 1"), VowpalArgsLearner("--cb_explore_adf --epsilon_decay --model_count 32 --interactions xxa --interactions xa --ignore_linear x --random_seed 1")]

Experiment(environments, learners).evaluate().plot_learners(each=True)
# Out:
# 2022-05-12 15:49:50 -- Processing chunk...
# 2022-05-12 15:49:50 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Recording Learner 2 parameters... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Recording Learner 3 parameters... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Recording Learner 4 parameters... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Loading Openml(id=181, cat_as_str=False)... (0.13 seconds) (completed)
# 2022-05-12 15:49:50 --   * Creating Environment 0 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:49:50 --   * Evaluating Learner 0 on Environment 0... (0.08 seconds) (completed)
# 2022-05-12 15:49:50 --   * Evaluating Learner 1 on Environment 0... (0.76 seconds) (completed)
# 2022-05-12 15:49:51 --   * Evaluating Learner 2 on Environment 0... (0.73 seconds) (completed)
# 2022-05-12 15:49:52 --   * Evaluating Learner 3 on Environment 0... (0.77 seconds) (completed)
# 2022-05-12 15:49:53 --   * Evaluating Learner 4 on Environment 0... (1.18 seconds) (completed)
# 2022-05-12 15:49:53 --   * Creating Environment 1 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:49:53 --   * Recording Environment 1 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:49:53 --   * Evaluating Learner 0 on Environment 1... (0.02 seconds) (completed)
# 2022-05-12 15:49:54 --   * Evaluating Learner 1 on Environment 1... (0.75 seconds) (completed)
# 2022-05-12 15:49:55 --   * Evaluating Learner 2 on Environment 1... (1.02 seconds) (completed)
# 2022-05-12 15:49:56 --   * Evaluating Learner 3 on Environment 1... (1.08 seconds) (completed)
# 2022-05-12 15:49:57 --   * Evaluating Learner 4 on Environment 1... (1.19 seconds) (completed)
# 2022-05-12 15:49:57 --   * Creating Environment 2 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:49:57 --   * Recording Environment 2 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:49:57 --   * Evaluating Learner 0 on Environment 2... (0.02 seconds) (completed)
# 2022-05-12 15:49:58 --   * Evaluating Learner 1 on Environment 2... (0.69 seconds) (completed)
# 2022-05-12 15:49:59 --   * Evaluating Learner 2 on Environment 2... (0.68 seconds) (completed)
# 2022-05-12 15:49:59 --   * Evaluating Learner 3 on Environment 2... (0.74 seconds) (completed)
# 2022-05-12 15:50:01 --   * Evaluating Learner 4 on Environment 2... (1.61 seconds) (completed)
# 2022-05-12 15:50:01 --   * Creating Environment 3 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:01 --   * Recording Environment 3 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:01 --   * Evaluating Learner 0 on Environment 3... (0.02 seconds) (completed)
# 2022-05-12 15:50:02 --   * Evaluating Learner 1 on Environment 3... (0.85 seconds) (completed)
# 2022-05-12 15:50:03 --   * Evaluating Learner 2 on Environment 3... (0.94 seconds) (completed)
# 2022-05-12 15:50:04 --   * Evaluating Learner 3 on Environment 3... (0.86 seconds) (completed)
# 2022-05-12 15:50:05 --   * Evaluating Learner 4 on Environment 3... (1.28 seconds) (completed)
# 2022-05-12 15:50:05 --   * Creating Environment 4 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:05 --   * Recording Environment 4 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:05 --   * Evaluating Learner 0 on Environment 4... (0.02 seconds) (completed)
# 2022-05-12 15:50:06 --   * Evaluating Learner 1 on Environment 4... (0.75 seconds) (completed)
# 2022-05-12 15:50:06 --   * Evaluating Learner 2 on Environment 4... (0.8 seconds) (completed)
# 2022-05-12 15:50:07 --   * Evaluating Learner 3 on Environment 4... (0.83 seconds) (completed)
# 2022-05-12 15:50:09 --   * Evaluating Learner 4 on Environment 4... (1.36 seconds) (completed)
# 2022-05-12 15:50:09 --   * Creating Environment 5 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:09 --   * Recording Environment 5 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:09 --   * Evaluating Learner 0 on Environment 5... (0.03 seconds) (completed)
# 2022-05-12 15:50:10 --   * Evaluating Learner 1 on Environment 5... (0.82 seconds) (completed)
# 2022-05-12 15:50:10 --   * Evaluating Learner 2 on Environment 5... (0.79 seconds) (completed)
# 2022-05-12 15:50:11 --   * Evaluating Learner 3 on Environment 5... (0.81 seconds) (completed)
# 2022-05-12 15:50:12 --   * Evaluating Learner 4 on Environment 5... (1.26 seconds) (completed)
# 2022-05-12 15:50:12 --   * Creating Environment 6 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:12 --   * Recording Environment 6 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:12 --   * Evaluating Learner 0 on Environment 6... (0.02 seconds) (completed)
# 2022-05-12 15:50:13 --   * Evaluating Learner 1 on Environment 6... (0.75 seconds) (completed)
# 2022-05-12 15:50:14 --   * Evaluating Learner 2 on Environment 6... (0.74 seconds) (completed)
# 2022-05-12 15:50:15 --   * Evaluating Learner 3 on Environment 6... (0.79 seconds) (completed)
# 2022-05-12 15:50:16 --   * Evaluating Learner 4 on Environment 6... (1.3 seconds) (completed)
# 2022-05-12 15:50:16 --   * Creating Environment 7 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:16 --   * Recording Environment 7 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:16 --   * Evaluating Learner 0 on Environment 7... (0.02 seconds) (completed)
# 2022-05-12 15:50:17 --   * Evaluating Learner 1 on Environment 7... (0.72 seconds) (completed)
# 2022-05-12 15:50:18 --   * Evaluating Learner 2 on Environment 7... (0.76 seconds) (completed)
# 2022-05-12 15:50:18 --   * Evaluating Learner 3 on Environment 7... (0.78 seconds) (completed)
# 2022-05-12 15:50:20 --   * Evaluating Learner 4 on Environment 7... (1.25 seconds) (completed)
# 2022-05-12 15:50:20 --   * Creating Environment 8 from Loaded Source... (0.0 seconds) (completed)
# 2022-05-12 15:50:20 --   * Recording Environment 8 statistics... (0.0 seconds) (completed)
# 2022-05-12 15:50:20 --   * Evaluating Learner 0 on Environment 8... (0.02 seconds) (completed)
# 2022-05-12 15:50:20 --   * Evaluating Learner 1 on Environment 8... (0.74 seconds) (completed)
# 2022-05-12 15:50:21 --   * Evaluating Learner 2 on Environment 8... (0.8 seconds) (completed)
# 2022-05-12 15:50:22 --   * Evaluating Learner 3 on Environment 8... (0.85 seconds) (completed)
# 2022-05-12 15:50:23 --   * Evaluating Learner 4 on Environment 8... (1.27 seconds) (completed)

# %% [markdown]
# This same procedure can be repeated for any dataset on Openml.org.
#
# ## Simulated Environments From Local Datasets
#
# The next easiest way to incorporate new environments is to load them from a local dataset. Coba can create SimulatedEnvironments from datasets in the following formats:
# * CSV
# * ARFF (i.e., https://waikato.github.io/weka-wiki/formats_and_processing/arff_stable/)
# * Libsvm (e.g., https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html)
# * Manik (e.g., http://manikvarma.org/downloads/XC/XMLRepository.html)
#
# For example, we may want to test against the mnist dataset. This dataset can be download from Libsvm [here](https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html#mnist). Once downloaded it we could use it:
#
# ```python
# from coba.environments import Environments, LibSvmSource
# from coba.learners     import RandomLearner, VowpalEpsilonLearner
# from coba.experiments  import Experiment
#
# mnist = Environments.from_supervised(LibSvmSource(<path to downloaded mnist>)).take(1000)
# Experiment(mnist,[RandomLearner(), VowpalEpsilonLearner()]).evaluate().plot_learners()
# ```
#
# The complete list of supported sources for local supervised data is:
#
# * `CsvSource(source:str, with_header:bool=True)`
# * `ArffSource(source:str, cat_as_str:bool=False)`
# * `LibSvmSource(source:str)`
# * `ManikSource(source:str)`
#
# ## Environments from Function Definitions
#
# A third method for creating environments for use in experiments is via function definitions.
#
# This can be done with **LambdaSimulation** which takes three function definitions -- describing how to generate contexts, actions and rewards -- and the number of interactions you'd like the environment to have. An example of a **LambdaSimulation** generating random contexts and actions with a linear reward function in [0,1] is provided:

# %%
from typing import Sequence

from coba.random       import CobaRandom
from coba.environments import Environments, LambdaSimulation, Context, Action
from coba.learners     import RandomLearner, VowpalEpsilonLearner
from coba.experiments  import Experiment

r = CobaRandom(1)
n_interactions = 1000

def context(index: int) -> Context:
    return tuple(r.randoms(5))

def actions(index: int, context: Context) -> Sequence[Action]:
    actions = [ r.randoms(5) for _ in range(3) ]
    return [ tuple(a/sum(action) for a in action) for action in actions ]

def rewards(index: int, context: Context, action: Action) -> float:
    return sum(c*a for c,a in zip(context,action))

environments = Environments([LambdaSimulation(n_interactions, context, actions, rewards)]).shuffle([1,2,3,4])

Experiment(environments, [VowpalEpsilonLearner(),RandomLearner()]).evaluate().plot_learners(sort='id')
# Out:
# 2022-03-15 15:54:08 -- Processing chunk...
# 2022-03-15 15:54:08 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2022-03-15 15:54:08 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2022-03-15 15:54:08 --   * Loading LambdaSimulation... (0.02 seconds) (completed)
# 2022-03-15 15:54:08 --   * Creating Environment 0 from Loaded Source... (0.0 seconds) (completed)
# 2022-03-15 15:54:08 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2022-03-15 15:54:08 --   * Evaluating Learner 0 on Environment 0... (0.02 seconds) (completed)
# 2022-03-15 15:54:08 --   * Evaluating Learner 1 on Environment 0... (0.15 seconds) (completed)

# %% [markdown]
# ## Environments from Scratch
#
# The final, and most involved method, for creating new SimulatedEnvironments in Coba is to create your own from scratch. This might be needed if you need to ingest a format that Coba doesn't already support. Or maybe you need your environment to track some internal state between interactions. By creating your own Simulation there really is no limit to the functionality employed. In order to make your own environment you need to implement the SimulatedEnvironment interface.
#
#
# ### SimulatedEnvironment Interface
#
# A SimulatedEnvironment in Coba is any class with the following interface:
#
# ```python
# class SimulatedEnvironment:
#
#     @abstractmethod
#     def read(self) -> Iterable[SimulatedInteraction]:
#         """The sequence of interactions in the environment.
#
#         Remarks:
#             This function should always be "re-iterable".
#         """
#         ...
#
# ```
#
# So long as your class satisfies this interface it should be completely interoperable with Coba. Below is an example:

# %%
from coba.environments import SimulatedInteraction
from coba.learners     import RandomLearner, EpsilonBanditLearner
from coba.experiments  import Experiment

class MySimulatedEnvironment:
    
    def read(self):
        for i in range(50):
            yield SimulatedInteraction(None, [1,2,3], rewards=[2,100,-100])

    def __str__(self):
        return "MySimulation"

Experiment([MySimulatedEnvironment()],[EpsilonBanditLearner(),RandomLearner()]).evaluate().plot_learners(sort='id')
# Out:
# 2022-04-10 17:07:10 -- Processing chunk...
# 2022-04-10 17:07:10 --   * Recording Learner 0 parameters... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Recording Learner 1 parameters... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Loading MySimulation... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Creating Environment 0 from Loaded Source... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Recording Environment 0 statistics... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Evaluating Learner 0 on Environment 0... (0.0 seconds) (completed)
# 2022-04-10 17:07:10 --   * Evaluating Learner 1 on Environment 0... (0.0 seconds) (completed)
